# %% [markdown]
# <a href="https://colab.research.google.com/github/andywag/streaming_data_loader/blob/master/BasicRunner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Rust and Cargo

# %%
# run this once, then reload, and then skip this
# !curl https://sh.rustup.rs -sSf | sh -s -- -y
# !cp /root/.cargo/bin/rustc /usr/bin
# !cp /root/.cargo/bin/cargo /usr/bin
# Out:
# info: downloading installer
# info: profile set to 'default'
# info: default host triple is x86_64-unknown-linux-gnu
# ...
# info: syncing channel updates for 'stable-x86_64-unknown-linux-gnu'
# info: default toolchain set to 'stable-x86_64-unknown-linux-gnu'
#
#   stable-x86_64-unknown-linux-gnu unchanged - rustc 1.66.0 (69f9c33d7 2022-12-12)
#
#
# Rust is installed now. Great!
#
# To get started you may need to restart your current shell.
# This would reload your PATH environment variable to include
# Cargo's bin directory ($HOME/.cargo/bin).
#
# To configure your current shell, run:
# source "$HOME/.cargo/env"
# Usage: rustc [OPTIONS] INPUT
#
# Options:
#     -h, --help          Display this message
#         --cfg SPEC      Configure the compilation environment
#     -L [KIND=]PATH      Add a directory to the library search path. The
#                         optional KIND can be one of dependency, crate, native,
#                         framework, or all (the default).
# ...

# %% [markdown]
# Mount google drive location to avoid recompiling rust project. It takes a relatively long time on the Google colab (Optional)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/andywag/streaming_data_loader.git
# %cd /content/streaming_data_loader/rust
# !cargo build --release
# %cd /content/streaming_data_loader/python/
# !pip3 install -r requirements.txt
# Out:
# Cloning into 'streaming_data_loader'...
# remote: Enumerating objects: 1374, done.
# remote: Counting objects: 100% (1374/1374), done.
# remote: Compressing objects: 100% (796/796), done.
# remote: Total 1374 (delta 906), reused 1018 (delta 550), pack-reused 0
# Receiving objects: 100% (1374/1374), 16.34 MiB | 34.94 MiB/s, done.
# Resolving deltas: 100% (906/906), done.
# /content/streaming_data_loader/rust
#     Updating crates.io index
# ...
#   Downloaded darling_macro v0.10.2
#   Downloaded foreign-types-shared v0.1.1
#   Downloaded crypto-common v0.1.6
#   Downloaded digest v0.10.5
#   Downloaded bytes v1.2.1
#   Downloaded aho-corasick v0.7.19
#   Downloaded onig v6.4.0
#   Downloaded number_prefix v0.4.0
#   Downloaded cfg-if v1.0.0
#   Downloaded half v2.1.0
#   Downloaded once_cell v1.15.0
#   Downloaded either v1.8.0
#   Downloaded clap_lex v0.3.0
#   Downloaded clap v2.34.0
#   Downloaded openssl-sys v0.9.76
#   Downloaded polling v2.4.0
#   Downloaded number_prefix v0.3.0
# ...

# %% [markdown]
# Run MLM Pretraining using streamed data.

# %%
# !python3 top_run.py --task mlm --all --cache .
# Out:
# /content/streaming_data_loader/python
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 5.9 MB/s
# ...
#      |████████████████████████████████| 451 kB 75.9 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 77.8 MB/s
# ...
#      |████████████████████████████████| 182 kB 81.5 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 63.9 MB/s
# ...
#      |████████████████████████████████| 212 kB 54.0 MB/s
# ...
#      |████████████████████████████████| 132 kB 86.6 MB/s
# ...
#      |████████████████████████████████| 127 kB 85.4 MB/s
# ...
#      |████████████████████████████████| 182 kB 81.9 MB/s
# ...
#      |████████████████████████████████| 173 kB 73.4 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 168 kB 88.3 MB/s
# ...
#      |████████████████████████████████| 168 kB 87.0 MB/s
# ...
#      |████████████████████████████████| 166 kB 85.5 MB/s
# ...
